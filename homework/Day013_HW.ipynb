# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
#可參考https://ithelp.ithome.com.tw/articles/10204709
'''
Your Code
'''
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)
soup = BeautifulSoup(r.text, "html5lib")
#soup

# %%
words=[]
for d in soup.find_all(class_="r-ent"):
    print(d.text.replace('\t', '').replace('\n', ''))
    print('作者: ' + d.find(class_='author').text,'標題: ' + d.find(class_='title').text,'日期: ' + d.find(class_='date').text)
    words.append([d.find(class_='author').text.replace('\t', '').replace('\n', ''),d.find(class_='title').text.replace('\t', '').replace('\n', ''),d.find(class_='date').text.replace('\t', '').replace('\n', '')])
# Out:
# 15[新聞] 老將Noah「百分之百健康」　本季有望重回PttGod⋯搜尋同標題文章搜尋看板內 PttGod 的文章 2/08
# 作者: PttGod 標題:
#
# 				[新聞] 老將Noah「百分之百健康」　本季有望重回
#
# 			 日期:  2/08
# 爆[情報]Lillard:罰款？我有的是錢cidexin⋯搜尋同標題文章搜尋看板內 cidexin 的文章 2/08
# 作者: cidexin 標題:
#
# 				[情報]Lillard:罰款？我有的是錢
#
# 			 日期:  2/08
# 27[新聞]讚湖人是奪冠熱門 莫雷：但火箭能擊敗他sodistrues⋯搜尋同標題文章搜尋看板內 sodistrues 的文章 2/08
# 作者: sodistrues 標題:
#
# 				[新聞]讚湖人是奪冠熱門 莫雷：但火箭能擊敗他
#
# 			 日期:  2/08
# 23[情報] Kemba得知Williams去公鹿:我要打電話給他thnlkj0665⋯搜尋同標題文章搜尋看板內 thnlkj0665 的文章 2/08
# 作者: thnlkj0665 標題:
#
# 				[情報] Kemba得知Williams去公鹿:我要打電話給他
#
# 			 日期:  2/08
# 30[情報]Booker17次以50+%命中率得分30+，僅次字母PttGod⋯搜尋同標題文章搜尋看板內 PttGod 的文章 2/08
# 作者: PttGod 標題:
#
# 				[情報]Booker17次以50+%命中率得分30+，僅次字母
#
# 			 日期:  2/08
# 14[新聞] 可能會長期合作 傳佐蒙德願續留騎士Gotham⋯搜尋同標題文章搜尋看板內 Gotham 的文章 2/08
# 作者: Gotham 標題:
#
# 				[新聞] 可能會長期合作 傳佐蒙德願續留騎士
#
# 			 日期:  2/08
# 13[情報] 尼克雇用新總裁Leon Roselens82801⋯搜尋同標題文章搜尋看板內 lens82801 的文章 2/08
# 作者: lens82801 標題:
#
# 				[情報] 尼克雇用新總裁Leon Rose
#
# 			 日期:  2/08
# 7Re: [新聞] 重磅交易》榜眼換狀元 美媒僅給勇士D+評價pkchu⋯搜尋同標題文章搜尋看板內 pkchu 的文章 2/09
# 作者: pkchu 標題:
#
# 				Re: [新聞] 重磅交易》榜眼換狀元 美媒僅給勇士D+評價
#
# 			 日期:  2/09
# 8(本文已被刪除) [VeryGoodBoy]- 2/09
# 作者: - 標題:
#
# 				(本文已被刪除) [VeryGoodBoy]
#
# 			 日期:  2/09
# 6[討論] Bol Bol 的未來BestlovexD⋯搜尋同標題文章搜尋看板內 BestlovexD 的文章 2/09
# 作者: BestlovexD 標題:
#
# 				[討論] Bol Bol 的未來
#
# 			 日期:  2/09
# 12Re: [情報] Kerr：當我們得到DLO時，我們也不確定heatthree⋯搜尋同標題文章搜尋看板內 heatthree 的文章 2/09
# 作者: heatthree 標題:
#
# 				Re: [情報] Kerr：當我們得到DLO時，我們也不確定
#
# 			 日期:  2/09
# 43[花邊]  Lillard在Instagram霸氣留言zxzx0212⋯搜尋同標題文章搜尋看板內 zxzx0212 的文章 2/09
# 作者: zxzx0212 標題:
#
# 				[花邊]  Lillard在Instagram霸氣留言
#
# 			 日期:  2/09
# [公告] 板規v6.8Vedan⋯搜尋同標題文章搜尋看板內 Vedan 的文章 5/24!
# 作者: Vedan 標題:
#
# 				[公告] 板規v6.8
#
# 			 日期:  5/24
# 爆[公告] 樂透取消及未來不再開啟樂透Vedan⋯搜尋同標題文章搜尋看板內 Vedan 的文章 6/24M
# 作者: Vedan 標題:
#
# 				[公告] 樂透取消及未來不再開啟樂透
#
# 			 日期:  6/24
# 39[公告] 版主上任相關事項 qazwsx879345⋯搜尋同標題文章搜尋看板內 qazwsx879345 的文章10/25
# 作者: qazwsx879345 標題:
#
# 				[公告] 版主上任相關事項
#
# 			 日期: 10/25
# 18[情報] SEASON Schedule 賽程 February 19–20Acetoxy⋯搜尋同標題文章搜尋看板內 Acetoxy 的文章 1/31
# 作者: Acetoxy 標題:
#
# 				[情報] SEASON Schedule 賽程 February 19–20
#
# 			 日期:  1/31

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
'''
Your Code
'''
import pandas as pd
tables=pd.DataFrame(words,columns=['作者','標題','時間'])
tables
# Out:
#               作者                                      標題     時間
# 0         PttGod              [新聞] 老將Noah「百分之百健康」　本季有望重回   2/08
# 1        cidexin                    [情報]Lillard:罰款？我有的是錢   2/08
# 2     sodistrues                 [新聞]讚湖人是奪冠熱門 莫雷：但火箭能擊敗他   2/08
# 3     thnlkj0665         [情報] Kemba得知Williams去公鹿:我要打電話給他   2/08
# 4         PttGod         [情報]Booker17次以50+%命中率得分30+，僅次字母   2/08
# 5         Gotham                  [新聞] 可能會長期合作 傳佐蒙德願續留騎士   2/08
# 6      lens82801                   [情報] 尼克雇用新總裁Leon Rose   2/08
# 7          pkchu          Re: [新聞] 重磅交易》榜眼換狀元 美媒僅給勇士D+評價   2/09
# 8              -                  (本文已被刪除) [VeryGoodBoy]   2/09
# 9     BestlovexD                        [討論] Bol Bol 的未來   2/09
# 10     heatthree          Re: [情報] Kerr：當我們得到DLO時，我們也不確定   2/09
# 11      zxzx0212             [花邊]  Lillard在Instagram霸氣留言   2/09
# 12         Vedan                             [公告] 板規v6.8   5/24
# 13         Vedan                      [公告] 樂透取消及未來不再開啟樂透   6/24
# 14  qazwsx879345                          [公告] 版主上任相關事項   10/25
# 15       Acetoxy  [情報] SEASON Schedule 賽程 February 19–20   1/31

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
'''
Your Code
'''
import requests
import pandas as pd
from bs4 import BeautifulSoup

url1 = 'https://www.ptt.cc/bbs/sex/index.html'
r1 = requests.get(url1,cookies={'over18': '1'})
soup1 = BeautifulSoup(r1.text, "html5lib")

sex=[]
for d in soup1.find_all(class_="r-ent"):
    print(d.text.replace('\t', '').replace('\n', ''))
    print('作者: ' + d.find(class_='author').text,'標題: ' + d.find(class_='title').text,'日期: ' + d.find(class_='date').text)
    sex.append([d.find(class_='author').text.replace('\t', '').replace('\n', ''),d.find(class_='title').text.replace('\t', '').replace('\n', ''),d.find(class_='date').text.replace('\t', '').replace('\n', '')])
# Out:
# 1[討論] 請問有人用過哈妮來這款保險套嗎Migolove⋯搜尋同標題文章搜尋看板內 Migolove 的文章 2/08
# 作者: Migolove 標題:
#
# 				[討論] 請問有人用過哈妮來這款保險套嗎
#
# 			 日期:  2/08
# 1[新聞] 一時性起 後患無窮 愛在安全情人節hvariables⋯搜尋同標題文章搜尋看板內 hvariables 的文章 2/08
# 作者: hvariables 標題:
#
# 				[新聞] 一時性起 後患無窮 愛在安全情人節
#
# 			 日期:  2/08
# 10[認真] 小怪獸二代選擇owen0908⋯搜尋同標題文章搜尋看板內 owen0908 的文章 2/08
# 作者: owen0908 標題:
#
# 				[認真] 小怪獸二代選擇
#
# 			 日期:  2/08
# 2[閒聊] 吃豆干遇見人妖qma52015⋯搜尋同標題文章搜尋看板內 qma52015 的文章 2/08
# 作者: qma52015 標題:
#
# 				[閒聊] 吃豆干遇見人妖
#
# 			 日期:  2/08
# 4<a88241050> 1-3-2 by 紅 - 2/08
# 作者: - 標題:
#
# 				<a88241050> 1-3-2 by 紅
#
# 			 日期:  2/08
# 2[公告] 水桶FallRed⋯搜尋同標題文章搜尋看板內 FallRed 的文章 2/09M
# 作者: FallRed 標題:
#
# 				[公告] 水桶
#
# 			 日期:  2/09
# 2[閒聊] 走店像在走廚房的境界a0800944939⋯搜尋同標題文章搜尋看板內 a0800944939 的文章 2/09
# 作者: a0800944939 標題:
#
# 				[閒聊] 走店像在走廚房的境界
#
# 			 日期:  2/09
# [公告] 西斯板規 Ver 6.2.9FallRed⋯搜尋同標題文章搜尋看板內 FallRed 的文章10/16!
# 作者: FallRed 標題:
#
# 				[公告] 西斯板規 Ver 6.2.9
#
# 			 日期: 10/16
# Fw: [公告] 請使用者多加注意我國保護兒少的法令FallRed⋯搜尋同標題文章搜尋看板內 FallRed 的文章 7/29!
# 作者: FallRed 標題:
#
# 				Fw: [公告] 請使用者多加注意我國保護兒少的法令
#
# 			 日期:  7/29
# 10[公告] 2019 冬季徵文 結果 暨 得獎名單Assisi⋯搜尋同標題文章搜尋看板內 Assisi 的文章 1/20M
# 作者: Assisi 標題:
#
# 				[公告] 2019 冬季徵文 結果 暨 得獎名單
#
# 			 日期:  1/20
# 34[公告] 2020 貳月 西斯置底閒聊區Assisi⋯搜尋同標題文章搜尋看板內 Assisi 的文章 2/02
# 作者: Assisi 標題:
#
# 				[公告] 2020 貳月 西斯置底閒聊區
#
# 			 日期:  2/02

# %%
table=pd.DataFrame(sex,columns=['作者','標題','時間'])
table
# Out:
#              作者                          標題     時間
# 0      Migolove        [討論] 請問有人用過哈妮來這款保險套嗎   2/08
# 1    hvariables      [新聞] 一時性起 後患無窮 愛在安全情人節   2/08
# 2      owen0908                [認真] 小怪獸二代選擇   2/08
# 3      qma52015                [閒聊] 吃豆干遇見人妖   2/08
# 4             -     <a88241050> 1-3-2 by 紅    2/08
# 5       FallRed                     [公告] 水桶   2/09
# 6   a0800944939             [閒聊] 走店像在走廚房的境界   2/09
# 7       FallRed         [公告] 西斯板規 Ver 6.2.9  10/16
# 8       FallRed  Fw: [公告] 請使用者多加注意我國保護兒少的法令   7/29
# 9        Assisi    [公告] 2019 冬季徵文 結果 暨 得獎名單   1/20
# 10       Assisi        [公告] 2020 貳月 西斯置底閒聊區   2/02
